# %%
# # This mounts your Google Drive to the Colab VM.
# from google.colab import drive
# drive.mount('/content/drive')

# # TODO: Enter the foldername in your Drive where you have saved the unzipped
# # assignment folder, e.g. 'cs231n/assignments/assignment1/'
# FOLDERNAME = 'cs231n/assignments/assignment1/'
# assert FOLDERNAME is not None, "[!] Enter the foldername."

# # Now that we've mounted your Drive, this ensures that
# # the Python interpreter of the Colab VM can load
# # python files from within it.
# import sys
# sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# # This downloads the CIFAR-10 dataset to your Drive
# # if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
import sys
sys.path.append('./cs231n')

import os
if not os.path.exists('cs231n/datasets/cifar-10-batches-py'):
    os.chdir('cs231n/datasets')
    # !bash get_datasets.sh
    os.chdir('../..')
else:
    print("Datasets already exist.")
# Out:
# Datasets already exist.

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

# num_color_bins = 10 # Number of bins in the color histogram
num_color_bins = 25 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train Softmax classifier on features
# Using the Softmax code developed earlier in the assignment, train Softmax classifiers on top of the features extracted above; this should achieve better results than training them directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import Softmax

learning_rates = [1e-7, 1e-6, 1e-5, 1e-4]
regularization_strengths = [1e4, 5e4, 1e5, 5e5, 1e6, 5e6]

results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the Softmax; save#
# the best trained classifer in best_softmax. If you carefully tune the model, #
# you should be able to get accuracy of above 0.42 on the validation set.      #
################################################################################

for lr in learning_rates:
    for rs in regularization_strengths:
        softmax = Softmax()
        softmax.train(X_train_feats, y_train, learning_rate=lr, reg=rs, num_iters=1000)
        y_train_predict = softmax.predict(X_train_feats)
        y_val_predict = softmax.predict(X_val_feats)
        train_accuracy = np.mean(y_train_predict == y_train)
        val_accuracy = np.mean(y_val_predict == y_val)
        results[(lr, rs)] = (train_accuracy, val_accuracy)

        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = softmax

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved: %f' % best_val)
# Out:
# /Users/ziyuanzhao/Documents/Develop/cs231n-assignments/assignment1/cs231n/classifiers/softmax.py:89: RuntimeWarning: divide by zero encountered in log
#   logprobs = -np.log(probs[np.arange(N), y])
# /Users/ziyuanzhao/Documents/Develop/cs231n-assignments/assignment1/cs231n/classifiers/softmax.py:90: RuntimeWarning: overflow encountered in scalar multiply
#   loss = np.sum(logprobs) / N + reg * np.sum(W * W)
# /Users/ziyuanzhao/Documents/Develop/cs231n-assignments/.venv/lib/python3.11/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/ziyuanzhao/Documents/Develop/cs231n-assignments/assignment1/cs231n/classifiers/softmax.py:90: RuntimeWarning: overflow encountered in multiply
#   loss = np.sum(logprobs) / N + reg * np.sum(W * W)
# /Users/ziyuanzhao/Documents/Develop/cs231n-assignments/assignment1/cs231n/classifiers/softmax.py:103: RuntimeWarning: overflow encountered in multiply
#   dW = X.T.dot(dscores) / N + 2 * reg * W
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.109612 val accuracy: 0.088000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.419449 val accuracy: 0.418000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.421163 val accuracy: 0.426000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.414429 val accuracy: 0.412000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.399531 val accuracy: 0.402000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.304163 val accuracy: 0.333000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.420755 val accuracy: 0.422000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.413531 val accuracy: 0.398000
# lr 1.000000e-06 reg 1.000000e+05 train accuracy: 0.397286 val accuracy: 0.386000
# lr 1.000000e-06 reg 5.000000e+05 train accuracy: 0.297510 val accuracy: 0.299000
# lr 1.000000e-06 reg 1.000000e+06 train accuracy: 0.106959 val accuracy: 0.110000
# lr 1.000000e-06 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 1.000000e+04 train accuracy: 0.410490 val accuracy: 0.406000
# lr 1.000000e-05 reg 5.000000e+04 train accuracy: 0.326102 val accuracy: 0.310000
# lr 1.000000e-05 reg 1.000000e+05 train accuracy: 0.091061 val accuracy: 0.102000
# lr 1.000000e-05 reg 5.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-04 reg 1.000000e+04 train accuracy: 0.139612 val accuracy: 0.157000
# lr 1.000000e-04 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-04 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-04 reg 5.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-04 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-04 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved: 0.426000

# %%
# Evaluate your trained Softmax on the test set: you should be able to get at least 0.42
y_test_pred = best_softmax.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.428

# %%
# Save best softmax model
best_softmax.save("best_softmax_features.npy")
# Out:
# best_softmax_features.npy saved.

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 170)
# (49000, 169)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats,
    'y_train': y_train,
    'X_val': X_val_feats,
    'y_val': y_val,
    'X_test': X_test_feats,
    'y_test': y_test,
}

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################

learning_rates = [5e-1, 1e-2, 5e-2, 1e-3]
regularization_strengths = [0.0, 1e-5, 5e-4]
best_val_acc = -1

for lr in learning_rates:
    for rs in regularization_strengths:
        model = TwoLayerNet(input_dim, hidden_dim, num_classes, reg=rs)
        solver = Solver(model, data,
                        optim_config={
                            'learning_rate': lr,
                        },
                        lr_decay=0.95,
                        num_epochs=25, batch_size=200,
                        print_every=2000)
        solver.train()

        val_acc = solver.val_acc_history[-1]
        train_acc = solver.train_acc_history[-1]

        print(f"lr: {lr}, reg: {rs}, Train acc: {train_acc}, Val acc: {val_acc}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_net = model
print(f"Best Val acc: {best_val_acc}")
# Out:
# (Iteration 1 / 6125) loss: 2.302625
# (Epoch 0 / 25) train acc: 0.104000; val_acc: 0.105000
# (Epoch 1 / 25) train acc: 0.534000; val_acc: 0.530000
# (Epoch 2 / 25) train acc: 0.575000; val_acc: 0.533000
# (Epoch 3 / 25) train acc: 0.600000; val_acc: 0.553000
# (Epoch 4 / 25) train acc: 0.644000; val_acc: 0.568000
# (Epoch 5 / 25) train acc: 0.679000; val_acc: 0.578000
# (Epoch 6 / 25) train acc: 0.714000; val_acc: 0.592000
# (Epoch 7 / 25) train acc: 0.710000; val_acc: 0.597000
# (Epoch 8 / 25) train acc: 0.753000; val_acc: 0.585000
# (Iteration 2001 / 6125) loss: 0.691272
# (Epoch 9 / 25) train acc: 0.721000; val_acc: 0.586000
# (Epoch 10 / 25) train acc: 0.763000; val_acc: 0.587000
# (Epoch 11 / 25) train acc: 0.798000; val_acc: 0.564000
# (Epoch 12 / 25) train acc: 0.826000; val_acc: 0.593000
# (Epoch 13 / 25) train acc: 0.823000; val_acc: 0.575000
# (Epoch 14 / 25) train acc: 0.872000; val_acc: 0.585000
# (Epoch 15 / 25) train acc: 0.835000; val_acc: 0.585000
# (Epoch 16 / 25) train acc: 0.864000; val_acc: 0.574000
# (Iteration 4001 / 6125) loss: 0.411458
# (Epoch 17 / 25) train acc: 0.871000; val_acc: 0.571000
# (Epoch 18 / 25) train acc: 0.892000; val_acc: 0.566000
# (Epoch 19 / 25) train acc: 0.897000; val_acc: 0.567000
# (Epoch 20 / 25) train acc: 0.909000; val_acc: 0.566000
# (Epoch 21 / 25) train acc: 0.929000; val_acc: 0.571000
# (Epoch 22 / 25) train acc: 0.919000; val_acc: 0.570000
# (Epoch 23 / 25) train acc: 0.937000; val_acc: 0.573000
# (Epoch 24 / 25) train acc: 0.949000; val_acc: 0.560000
# (Iteration 6001 / 6125) loss: 0.235473
# (Epoch 25 / 25) train acc: 0.952000; val_acc: 0.556000
# lr: 0.5, reg: 0.0, Train acc: 0.952, Val acc: 0.556
# (Iteration 1 / 6125) loss: 2.302585
# (Epoch 0 / 25) train acc: 0.100000; val_acc: 0.078000
# (Epoch 1 / 25) train acc: 0.520000; val_acc: 0.531000
# (Epoch 2 / 25) train acc: 0.598000; val_acc: 0.560000
# (Epoch 3 / 25) train acc: 0.605000; val_acc: 0.553000
# (Epoch 4 / 25) train acc: 0.660000; val_acc: 0.581000
# (Epoch 5 / 25) train acc: 0.679000; val_acc: 0.595000
# (Epoch 6 / 25) train acc: 0.713000; val_acc: 0.589000
# (Epoch 7 / 25) train acc: 0.733000; val_acc: 0.586000
# (Epoch 8 / 25) train acc: 0.723000; val_acc: 0.580000
# (Iteration 2001 / 6125) loss: 0.720253
# (Epoch 9 / 25) train acc: 0.760000; val_acc: 0.580000
# (Epoch 10 / 25) train acc: 0.781000; val_acc: 0.577000
# (Epoch 11 / 25) train acc: 0.796000; val_acc: 0.589000
# (Epoch 12 / 25) train acc: 0.805000; val_acc: 0.566000
# (Epoch 13 / 25) train acc: 0.849000; val_acc: 0.580000
# (Epoch 14 / 25) train acc: 0.845000; val_acc: 0.567000
# (Epoch 15 / 25) train acc: 0.860000; val_acc: 0.569000
# (Epoch 16 / 25) train acc: 0.875000; val_acc: 0.593000
# (Iteration 4001 / 6125) loss: 0.358048
# (Epoch 17 / 25) train acc: 0.862000; val_acc: 0.587000
# (Epoch 18 / 25) train acc: 0.899000; val_acc: 0.581000
# (Epoch 19 / 25) train acc: 0.910000; val_acc: 0.563000
# (Epoch 20 / 25) train acc: 0.909000; val_acc: 0.574000
# (Epoch 21 / 25) train acc: 0.922000; val_acc: 0.564000
# (Epoch 22 / 25) train acc: 0.934000; val_acc: 0.573000
# (Epoch 23 / 25) train acc: 0.932000; val_acc: 0.559000
# (Epoch 24 / 25) train acc: 0.934000; val_acc: 0.562000
# (Iteration 6001 / 6125) loss: 0.239687
# (Epoch 25 / 25) train acc: 0.949000; val_acc: 0.554000
# lr: 0.5, reg: 1e-05, Train acc: 0.949, Val acc: 0.554
# (Iteration 1 / 6125) loss: 2.302605
# (Epoch 0 / 25) train acc: 0.096000; val_acc: 0.078000
# (Epoch 1 / 25) train acc: 0.538000; val_acc: 0.517000
# (Epoch 2 / 25) train acc: 0.593000; val_acc: 0.551000
# (Epoch 3 / 25) train acc: 0.608000; val_acc: 0.585000
# (Epoch 4 / 25) train acc: 0.598000; val_acc: 0.554000
# (Epoch 5 / 25) train acc: 0.651000; val_acc: 0.585000
# (Epoch 6 / 25) train acc: 0.690000; val_acc: 0.576000
# (Epoch 7 / 25) train acc: 0.729000; val_acc: 0.577000
# (Epoch 8 / 25) train acc: 0.722000; val_acc: 0.581000
# (Iteration 2001 / 6125) loss: 0.823711
# (Epoch 9 / 25) train acc: 0.757000; val_acc: 0.583000
# (Epoch 10 / 25) train acc: 0.764000; val_acc: 0.602000
# (Epoch 11 / 25) train acc: 0.791000; val_acc: 0.586000
# (Epoch 12 / 25) train acc: 0.814000; val_acc: 0.592000
# (Epoch 13 / 25) train acc: 0.813000; val_acc: 0.585000
# (Epoch 14 / 25) train acc: 0.821000; val_acc: 0.589000
# (Epoch 15 / 25) train acc: 0.843000; val_acc: 0.598000
# (Epoch 16 / 25) train acc: 0.841000; val_acc: 0.574000
# (Iteration 4001 / 6125) loss: 0.662160
# (Epoch 17 / 25) train acc: 0.864000; val_acc: 0.578000
# (Epoch 18 / 25) train acc: 0.851000; val_acc: 0.588000
# (Epoch 19 / 25) train acc: 0.868000; val_acc: 0.586000
# (Epoch 20 / 25) train acc: 0.886000; val_acc: 0.585000
# (Epoch 21 / 25) train acc: 0.887000; val_acc: 0.602000
# (Epoch 22 / 25) train acc: 0.892000; val_acc: 0.591000
# (Epoch 23 / 25) train acc: 0.890000; val_acc: 0.579000
# (Epoch 24 / 25) train acc: 0.896000; val_acc: 0.580000
# (Iteration 6001 / 6125) loss: 0.532379
# (Epoch 25 / 25) train acc: 0.889000; val_acc: 0.583000
# lr: 0.5, reg: 0.0005, Train acc: 0.889, Val acc: 0.583
# (Iteration 1 / 6125) loss: 2.302576
# (Epoch 0 / 25) train acc: 0.099000; val_acc: 0.089000
# (Epoch 1 / 25) train acc: 0.183000; val_acc: 0.138000
# (Epoch 2 / 25) train acc: 0.187000; val_acc: 0.134000
# (Epoch 3 / 25) train acc: 0.268000; val_acc: 0.273000
# (Epoch 4 / 25) train acc: 0.252000; val_acc: 0.257000
# (Epoch 5 / 25) train acc: 0.261000; val_acc: 0.268000
# (Epoch 6 / 25) train acc: 0.283000; val_acc: 0.289000
# (Epoch 7 / 25) train acc: 0.279000; val_acc: 0.315000
# (Epoch 8 / 25) train acc: 0.331000; val_acc: 0.336000
# (Iteration 2001 / 6125) loss: 1.859496
# (Epoch 9 / 25) train acc: 0.343000; val_acc: 0.362000
# (Epoch 10 / 25) train acc: 0.401000; val_acc: 0.381000
# (Epoch 11 / 25) train acc: 0.419000; val_acc: 0.391000
# (Epoch 12 / 25) train acc: 0.386000; val_acc: 0.392000
# (Epoch 13 / 25) train acc: 0.404000; val_acc: 0.395000
# (Epoch 14 / 25) train acc: 0.429000; val_acc: 0.417000
# (Epoch 15 / 25) train acc: 0.435000; val_acc: 0.423000
# (Epoch 16 / 25) train acc: 0.457000; val_acc: 0.428000
# (Iteration 4001 / 6125) loss: 1.454331
# (Epoch 17 / 25) train acc: 0.435000; val_acc: 0.445000
# (Epoch 18 / 25) train acc: 0.463000; val_acc: 0.448000
# (Epoch 19 / 25) train acc: 0.452000; val_acc: 0.452000
# (Epoch 20 / 25) train acc: 0.455000; val_acc: 0.457000
# (Epoch 21 / 25) train acc: 0.509000; val_acc: 0.466000
# (Epoch 22 / 25) train acc: 0.484000; val_acc: 0.469000
# (Epoch 23 / 25) train acc: 0.483000; val_acc: 0.472000
# (Epoch 24 / 25) train acc: 0.488000; val_acc: 0.478000
# (Iteration 6001 / 6125) loss: 1.477848
# (Epoch 25 / 25) train acc: 0.465000; val_acc: 0.482000
# lr: 0.01, reg: 0.0, Train acc: 0.465, Val acc: 0.482
# (Iteration 1 / 6125) loss: 2.302604
# (Epoch 0 / 25) train acc: 0.116000; val_acc: 0.103000
# (Epoch 1 / 25) train acc: 0.151000; val_acc: 0.120000
# (Epoch 2 / 25) train acc: 0.232000; val_acc: 0.212000
# (Epoch 3 / 25) train acc: 0.249000; val_acc: 0.246000
# (Epoch 4 / 25) train acc: 0.264000; val_acc: 0.271000
# (Epoch 5 / 25) train acc: 0.297000; val_acc: 0.279000
# (Epoch 6 / 25) train acc: 0.313000; val_acc: 0.307000
# (Epoch 7 / 25) train acc: 0.328000; val_acc: 0.330000
# (Epoch 8 / 25) train acc: 0.330000; val_acc: 0.346000
# (Iteration 2001 / 6125) loss: 1.804210
# (Epoch 9 / 25) train acc: 0.396000; val_acc: 0.367000
# (Epoch 10 / 25) train acc: 0.351000; val_acc: 0.376000
# (Epoch 11 / 25) train acc: 0.385000; val_acc: 0.387000
# (Epoch 12 / 25) train acc: 0.396000; val_acc: 0.404000
# (Epoch 13 / 25) train acc: 0.423000; val_acc: 0.405000
# (Epoch 14 / 25) train acc: 0.435000; val_acc: 0.416000
# (Epoch 15 / 25) train acc: 0.442000; val_acc: 0.420000
# (Epoch 16 / 25) train acc: 0.421000; val_acc: 0.432000
# (Iteration 4001 / 6125) loss: 1.545704
# (Epoch 17 / 25) train acc: 0.460000; val_acc: 0.442000
# (Epoch 18 / 25) train acc: 0.450000; val_acc: 0.447000
# (Epoch 19 / 25) train acc: 0.471000; val_acc: 0.451000
# (Epoch 20 / 25) train acc: 0.502000; val_acc: 0.458000
# (Epoch 21 / 25) train acc: 0.475000; val_acc: 0.463000
# (Epoch 22 / 25) train acc: 0.466000; val_acc: 0.466000
# (Epoch 23 / 25) train acc: 0.463000; val_acc: 0.467000
# (Epoch 24 / 25) train acc: 0.453000; val_acc: 0.469000
# (Iteration 6001 / 6125) loss: 1.344903
# (Epoch 25 / 25) train acc: 0.504000; val_acc: 0.474000
# lr: 0.01, reg: 1e-05, Train acc: 0.504, Val acc: 0.474
# (Iteration 1 / 6125) loss: 2.302601
# (Epoch 0 / 25) train acc: 0.077000; val_acc: 0.096000
# (Epoch 1 / 25) train acc: 0.104000; val_acc: 0.113000
# (Epoch 2 / 25) train acc: 0.206000; val_acc: 0.186000
# (Epoch 3 / 25) train acc: 0.254000; val_acc: 0.261000
# (Epoch 4 / 25) train acc: 0.290000; val_acc: 0.287000
# (Epoch 5 / 25) train acc: 0.254000; val_acc: 0.271000
# (Epoch 6 / 25) train acc: 0.290000; val_acc: 0.296000
# (Epoch 7 / 25) train acc: 0.288000; val_acc: 0.324000
# (Epoch 8 / 25) train acc: 0.323000; val_acc: 0.344000
# (Iteration 2001 / 6125) loss: 1.802603
# (Epoch 9 / 25) train acc: 0.363000; val_acc: 0.362000
# (Epoch 10 / 25) train acc: 0.368000; val_acc: 0.373000
# (Epoch 11 / 25) train acc: 0.400000; val_acc: 0.387000
# (Epoch 12 / 25) train acc: 0.404000; val_acc: 0.397000
# (Epoch 13 / 25) train acc: 0.434000; val_acc: 0.414000
# (Epoch 14 / 25) train acc: 0.453000; val_acc: 0.419000
# (Epoch 15 / 25) train acc: 0.460000; val_acc: 0.425000
# (Epoch 16 / 25) train acc: 0.447000; val_acc: 0.437000
# (Iteration 4001 / 6125) loss: 1.563576
# (Epoch 17 / 25) train acc: 0.461000; val_acc: 0.449000
# (Epoch 18 / 25) train acc: 0.460000; val_acc: 0.453000
# (Epoch 19 / 25) train acc: 0.463000; val_acc: 0.455000
# (Epoch 20 / 25) train acc: 0.488000; val_acc: 0.460000
# (Epoch 21 / 25) train acc: 0.461000; val_acc: 0.460000
# (Epoch 22 / 25) train acc: 0.456000; val_acc: 0.463000
# (Epoch 23 / 25) train acc: 0.461000; val_acc: 0.466000
# (Epoch 24 / 25) train acc: 0.492000; val_acc: 0.469000
# (Iteration 6001 / 6125) loss: 1.425218
# (Epoch 25 / 25) train acc: 0.484000; val_acc: 0.476000
# lr: 0.01, reg: 0.0005, Train acc: 0.484, Val acc: 0.476
# (Iteration 1 / 6125) loss: 2.302597
# (Epoch 0 / 25) train acc: 0.100000; val_acc: 0.097000
# (Epoch 1 / 25) train acc: 0.273000; val_acc: 0.293000
# (Epoch 2 / 25) train acc: 0.410000; val_acc: 0.419000
# (Epoch 3 / 25) train acc: 0.464000; val_acc: 0.478000
# (Epoch 4 / 25) train acc: 0.513000; val_acc: 0.516000
# (Epoch 5 / 25) train acc: 0.506000; val_acc: 0.521000
# (Epoch 6 / 25) train acc: 0.540000; val_acc: 0.519000
# (Epoch 7 / 25) train acc: 0.516000; val_acc: 0.525000
# (Epoch 8 / 25) train acc: 0.530000; val_acc: 0.516000
# (Iteration 2001 / 6125) loss: 1.370805
# (Epoch 9 / 25) train acc: 0.530000; val_acc: 0.530000
# (Epoch 10 / 25) train acc: 0.553000; val_acc: 0.534000
# (Epoch 11 / 25) train acc: 0.567000; val_acc: 0.540000
# (Epoch 12 / 25) train acc: 0.553000; val_acc: 0.537000
# (Epoch 13 / 25) train acc: 0.552000; val_acc: 0.537000
# (Epoch 14 / 25) train acc: 0.545000; val_acc: 0.549000
# (Epoch 15 / 25) train acc: 0.556000; val_acc: 0.544000
# (Epoch 16 / 25) train acc: 0.583000; val_acc: 0.550000
# (Iteration 4001 / 6125) loss: 1.253154
# (Epoch 17 / 25) train acc: 0.600000; val_acc: 0.550000
# (Epoch 18 / 25) train acc: 0.583000; val_acc: 0.554000
# (Epoch 19 / 25) train acc: 0.570000; val_acc: 0.555000
# (Epoch 20 / 25) train acc: 0.570000; val_acc: 0.557000
# (Epoch 21 / 25) train acc: 0.600000; val_acc: 0.563000
# (Epoch 22 / 25) train acc: 0.592000; val_acc: 0.565000
# (Epoch 23 / 25) train acc: 0.588000; val_acc: 0.571000
# (Epoch 24 / 25) train acc: 0.599000; val_acc: 0.565000
# (Iteration 6001 / 6125) loss: 1.259498
# (Epoch 25 / 25) train acc: 0.589000; val_acc: 0.571000
# lr: 0.05, reg: 0.0, Train acc: 0.589, Val acc: 0.571
# (Iteration 1 / 6125) loss: 2.302568
# (Epoch 0 / 25) train acc: 0.108000; val_acc: 0.103000
# (Epoch 1 / 25) train acc: 0.268000; val_acc: 0.293000
# (Epoch 2 / 25) train acc: 0.415000; val_acc: 0.414000
# (Epoch 3 / 25) train acc: 0.497000; val_acc: 0.462000
# (Epoch 4 / 25) train acc: 0.502000; val_acc: 0.505000
# (Epoch 5 / 25) train acc: 0.534000; val_acc: 0.511000
# (Epoch 6 / 25) train acc: 0.507000; val_acc: 0.522000
# (Epoch 7 / 25) train acc: 0.506000; val_acc: 0.513000
# (Epoch 8 / 25) train acc: 0.553000; val_acc: 0.519000
# (Iteration 2001 / 6125) loss: 1.319980
# (Epoch 9 / 25) train acc: 0.523000; val_acc: 0.528000
# (Epoch 10 / 25) train acc: 0.534000; val_acc: 0.534000
# (Epoch 11 / 25) train acc: 0.515000; val_acc: 0.531000
# (Epoch 12 / 25) train acc: 0.550000; val_acc: 0.541000
# (Epoch 13 / 25) train acc: 0.562000; val_acc: 0.542000
# (Epoch 14 / 25) train acc: 0.538000; val_acc: 0.538000
# (Epoch 15 / 25) train acc: 0.569000; val_acc: 0.547000
# (Epoch 16 / 25) train acc: 0.563000; val_acc: 0.544000
# (Iteration 4001 / 6125) loss: 1.138879
# (Epoch 17 / 25) train acc: 0.561000; val_acc: 0.545000
# (Epoch 18 / 25) train acc: 0.577000; val_acc: 0.550000
# (Epoch 19 / 25) train acc: 0.565000; val_acc: 0.555000
# (Epoch 20 / 25) train acc: 0.599000; val_acc: 0.549000
# (Epoch 21 / 25) train acc: 0.618000; val_acc: 0.553000
# (Epoch 22 / 25) train acc: 0.587000; val_acc: 0.561000
# (Epoch 23 / 25) train acc: 0.583000; val_acc: 0.552000
# (Epoch 24 / 25) train acc: 0.598000; val_acc: 0.558000
# (Iteration 6001 / 6125) loss: 1.229869
# (Epoch 25 / 25) train acc: 0.593000; val_acc: 0.565000
# lr: 0.05, reg: 1e-05, Train acc: 0.593, Val acc: 0.565
# (Iteration 1 / 6125) loss: 2.302624
# (Epoch 0 / 25) train acc: 0.095000; val_acc: 0.080000
# (Epoch 1 / 25) train acc: 0.235000; val_acc: 0.266000
# (Epoch 2 / 25) train acc: 0.443000; val_acc: 0.405000
# (Epoch 3 / 25) train acc: 0.501000; val_acc: 0.472000
# (Epoch 4 / 25) train acc: 0.481000; val_acc: 0.510000
# (Epoch 5 / 25) train acc: 0.531000; val_acc: 0.513000
# (Epoch 6 / 25) train acc: 0.541000; val_acc: 0.520000
# (Epoch 7 / 25) train acc: 0.558000; val_acc: 0.516000
# (Epoch 8 / 25) train acc: 0.534000; val_acc: 0.535000
# (Iteration 2001 / 6125) loss: 1.232672
# (Epoch 9 / 25) train acc: 0.551000; val_acc: 0.532000
# (Epoch 10 / 25) train acc: 0.543000; val_acc: 0.526000
# (Epoch 11 / 25) train acc: 0.535000; val_acc: 0.532000
# (Epoch 12 / 25) train acc: 0.575000; val_acc: 0.542000
# (Epoch 13 / 25) train acc: 0.542000; val_acc: 0.544000
# (Epoch 14 / 25) train acc: 0.568000; val_acc: 0.553000
# (Epoch 15 / 25) train acc: 0.534000; val_acc: 0.546000
# (Epoch 16 / 25) train acc: 0.575000; val_acc: 0.555000
# (Iteration 4001 / 6125) loss: 1.129651
# (Epoch 17 / 25) train acc: 0.584000; val_acc: 0.551000
# (Epoch 18 / 25) train acc: 0.578000; val_acc: 0.547000
# (Epoch 19 / 25) train acc: 0.596000; val_acc: 0.552000
# (Epoch 20 / 25) train acc: 0.567000; val_acc: 0.557000
# (Epoch 21 / 25) train acc: 0.559000; val_acc: 0.553000
# (Epoch 22 / 25) train acc: 0.600000; val_acc: 0.554000
# (Epoch 23 / 25) train acc: 0.570000; val_acc: 0.559000
# (Epoch 24 / 25) train acc: 0.579000; val_acc: 0.558000
# (Iteration 6001 / 6125) loss: 1.224453
# (Epoch 25 / 25) train acc: 0.573000; val_acc: 0.564000
# lr: 0.05, reg: 0.0005, Train acc: 0.573, Val acc: 0.564
# (Iteration 1 / 6125) loss: 2.302602
# (Epoch 0 / 25) train acc: 0.088000; val_acc: 0.090000
# (Epoch 1 / 25) train acc: 0.126000; val_acc: 0.152000
# (Epoch 2 / 25) train acc: 0.140000; val_acc: 0.132000
# (Epoch 3 / 25) train acc: 0.195000; val_acc: 0.160000
# (Epoch 4 / 25) train acc: 0.163000; val_acc: 0.154000
# (Epoch 5 / 25) train acc: 0.186000; val_acc: 0.176000
# (Epoch 6 / 25) train acc: 0.170000; val_acc: 0.195000
# (Epoch 7 / 25) train acc: 0.157000; val_acc: 0.171000
# (Epoch 8 / 25) train acc: 0.163000; val_acc: 0.167000
# (Iteration 2001 / 6125) loss: 2.302210
# (Epoch 9 / 25) train acc: 0.154000; val_acc: 0.145000
# (Epoch 10 / 25) train acc: 0.140000; val_acc: 0.116000
# (Epoch 11 / 25) train acc: 0.130000; val_acc: 0.114000
# (Epoch 12 / 25) train acc: 0.137000; val_acc: 0.116000
# (Epoch 13 / 25) train acc: 0.148000; val_acc: 0.129000
# (Epoch 14 / 25) train acc: 0.147000; val_acc: 0.135000
# (Epoch 15 / 25) train acc: 0.164000; val_acc: 0.149000
# (Epoch 16 / 25) train acc: 0.151000; val_acc: 0.162000
# (Iteration 4001 / 6125) loss: 2.301665
# (Epoch 17 / 25) train acc: 0.144000; val_acc: 0.152000
# (Epoch 18 / 25) train acc: 0.167000; val_acc: 0.151000
# (Epoch 19 / 25) train acc: 0.159000; val_acc: 0.145000
# (Epoch 20 / 25) train acc: 0.160000; val_acc: 0.149000
# (Epoch 21 / 25) train acc: 0.205000; val_acc: 0.164000
# (Epoch 22 / 25) train acc: 0.190000; val_acc: 0.152000
# (Epoch 23 / 25) train acc: 0.189000; val_acc: 0.154000
# (Epoch 24 / 25) train acc: 0.184000; val_acc: 0.165000
# (Iteration 6001 / 6125) loss: 2.301346
# (Epoch 25 / 25) train acc: 0.169000; val_acc: 0.171000
# lr: 0.001, reg: 0.0, Train acc: 0.169, Val acc: 0.171
# (Iteration 1 / 6125) loss: 2.302624
# (Epoch 0 / 25) train acc: 0.094000; val_acc: 0.099000
# (Epoch 1 / 25) train acc: 0.124000; val_acc: 0.116000
# (Epoch 2 / 25) train acc: 0.138000; val_acc: 0.141000
# (Epoch 3 / 25) train acc: 0.175000; val_acc: 0.157000
# (Epoch 4 / 25) train acc: 0.179000; val_acc: 0.160000
# (Epoch 5 / 25) train acc: 0.208000; val_acc: 0.201000
# (Epoch 6 / 25) train acc: 0.198000; val_acc: 0.176000
# (Epoch 7 / 25) train acc: 0.210000; val_acc: 0.194000
# (Epoch 8 / 25) train acc: 0.202000; val_acc: 0.225000
# (Iteration 2001 / 6125) loss: 2.302289
# (Epoch 9 / 25) train acc: 0.246000; val_acc: 0.228000
# (Epoch 10 / 25) train acc: 0.253000; val_acc: 0.212000
# (Epoch 11 / 25) train acc: 0.243000; val_acc: 0.227000
# (Epoch 12 / 25) train acc: 0.229000; val_acc: 0.221000
# (Epoch 13 / 25) train acc: 0.263000; val_acc: 0.244000
# (Epoch 14 / 25) train acc: 0.283000; val_acc: 0.243000
# (Epoch 15 / 25) train acc: 0.257000; val_acc: 0.228000
# (Epoch 16 / 25) train acc: 0.251000; val_acc: 0.219000
# (Iteration 4001 / 6125) loss: 2.301763
# (Epoch 17 / 25) train acc: 0.237000; val_acc: 0.218000
# (Epoch 18 / 25) train acc: 0.236000; val_acc: 0.215000
# (Epoch 19 / 25) train acc: 0.259000; val_acc: 0.222000
# (Epoch 20 / 25) train acc: 0.249000; val_acc: 0.226000
# (Epoch 21 / 25) train acc: 0.260000; val_acc: 0.230000
# (Epoch 22 / 25) train acc: 0.278000; val_acc: 0.250000
# (Epoch 23 / 25) train acc: 0.271000; val_acc: 0.247000
# (Epoch 24 / 25) train acc: 0.248000; val_acc: 0.246000
# (Iteration 6001 / 6125) loss: 2.301089
# (Epoch 25 / 25) train acc: 0.270000; val_acc: 0.244000
# lr: 0.001, reg: 1e-05, Train acc: 0.27, Val acc: 0.244
# (Iteration 1 / 6125) loss: 2.302622
# (Epoch 0 / 25) train acc: 0.111000; val_acc: 0.088000
# (Epoch 1 / 25) train acc: 0.120000; val_acc: 0.103000
# (Epoch 2 / 25) train acc: 0.154000; val_acc: 0.141000
# (Epoch 3 / 25) train acc: 0.255000; val_acc: 0.182000
# (Epoch 4 / 25) train acc: 0.168000; val_acc: 0.139000
# (Epoch 5 / 25) train acc: 0.180000; val_acc: 0.172000
# (Epoch 6 / 25) train acc: 0.167000; val_acc: 0.168000
# (Epoch 7 / 25) train acc: 0.215000; val_acc: 0.185000
# (Epoch 8 / 25) train acc: 0.213000; val_acc: 0.216000
# (Iteration 2001 / 6125) loss: 2.302171
# (Epoch 9 / 25) train acc: 0.235000; val_acc: 0.218000
# (Epoch 10 / 25) train acc: 0.241000; val_acc: 0.223000
# (Epoch 11 / 25) train acc: 0.217000; val_acc: 0.227000
# (Epoch 12 / 25) train acc: 0.257000; val_acc: 0.231000
# (Epoch 13 / 25) train acc: 0.228000; val_acc: 0.219000
# (Epoch 14 / 25) train acc: 0.247000; val_acc: 0.222000
# (Epoch 15 / 25) train acc: 0.260000; val_acc: 0.230000
# (Epoch 16 / 25) train acc: 0.270000; val_acc: 0.235000
# (Iteration 4001 / 6125) loss: 2.301712
# (Epoch 17 / 25) train acc: 0.247000; val_acc: 0.225000
# (Epoch 18 / 25) train acc: 0.262000; val_acc: 0.236000
# (Epoch 19 / 25) train acc: 0.238000; val_acc: 0.227000
# (Epoch 20 / 25) train acc: 0.272000; val_acc: 0.244000
# (Epoch 21 / 25) train acc: 0.274000; val_acc: 0.237000
# (Epoch 22 / 25) train acc: 0.264000; val_acc: 0.242000
# (Epoch 23 / 25) train acc: 0.265000; val_acc: 0.247000
# (Epoch 24 / 25) train acc: 0.289000; val_acc: 0.243000
# (Iteration 6001 / 6125) loss: 2.301307
# (Epoch 25 / 25) train acc: 0.295000; val_acc: 0.245000
# lr: 0.001, reg: 0.0005, Train acc: 0.295, Val acc: 0.245
# Best Val acc: 0.583

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 58% accuracy. It is also possible to get >60% accuracy
# with careful tuning.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.597

# %%
# Save best model
best_net.save("best_two_layer_net_features.npy")
# Out:
# best_two_layer_net_features.npy saved.
